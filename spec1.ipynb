# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
spec=fits.open("spec-55859-F5902_sp01-008.fits")
specdata = spec[0].data
flux1=specdata[0]
wavelenth=specdata[2]
print(flux1)
print(flux1.max())
print(flux1.min())
print(wavelenth)
print(wavelenth.max())
print(wavelenth.min())
x=np.arange(3699,9098)
x1=wavelenth
y1=flux1
plt.plot(x1,y1,'',color = 'black',label="SPEC",linewidth=0.3)#o-:圆形
plt.vlines(4100, -60, 336, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4340, -60, 336, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4860, -60, 336, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(6560, -60, 336, colors="c", linestyles="dashed",linewidth=0.2)
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
# l1=plt.plot(x1,y1,'r--',label='type1')
# plt.plot(x1,y1,'ro-')
plt.title('spec-55859-F5902_sp01-008.fits')
plt.xlabel('wavelength(0.1nm)')
plt.ylabel('flux(relative)')
plt.legend()
plt.savefig('./specF9.png')
plt.show()
# Out:
# [290.58572 205.58238 288.73767 ...   0.        0.        0.     ]
# 335.25522
# -60.567463
# [3699.9863 3700.8384 3701.6907 ... 9092.852  9094.945  9097.04  ]
# 9097.04
# 3699.9863

# %% [markdown]
# 这是一个F9星体

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
spec=fits.open("spec-55859-F5902_sp01-016.fits")
specdata = spec[0].data
flux1=specdata[0]
wavelenth=specdata[2]
print(flux1)
print(flux1.max())
print(flux1.min())
print(wavelenth)
print(wavelenth.max())
print(wavelenth.min())
x=np.arange(3699,9098)
x1=wavelenth
y1=flux1
plt.plot(x1,y1,'',color = 'black',label="SPEC",linewidth=0.3)#o-:圆形
plt.vlines(4100, -113, 348, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4340, -113, 348, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4860, -113, 348, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(6560, -113, 348, colors="c", linestyles="dashed",linewidth=0.2)
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
# l1=plt.plot(x1,y1,'r--',label='type1')
# plt.plot(x1,y1,'ro-')
plt.title('spec-55859-F5902_sp01-016.fits')
plt.xlabel('wavelength')
plt.ylabel('flux')
plt.legend()
plt.savefig('./specK3.png')
plt.show()
# Out:
# [159.59048 155.89601 120.23782 ...   0.        0.        0.     ]
# 347.33234
# -112.61979
# [3699.9863 3700.8384 3701.6907 ... 9092.852  9094.945  9097.04  ]
# 9097.04
# 3699.9863

# %% [markdown]
# k3

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
spec=fits.open("spec-55859-F5902_sp01-017.fits")
specdata = spec[0].data
flux1=specdata[0]
wavelenth=specdata[2]
print(flux1)
print(flux1.max())
print(flux1.min())
print(wavelenth)
print(wavelenth.max())
print(wavelenth.min())
x=np.arange(3699,9098)
x1=wavelenth
y1=flux1
plt.plot(x1,y1,'',color = 'black',label="SPEC",linewidth=0.3)#o-:圆形
plt.vlines(4100, -81, 354, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4340, -81, 354, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4860, -81, 354, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(6560, -81, 354, colors="c", linestyles="dashed",linewidth=0.2)
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
# l1=plt.plot(x1,y1,'r--',label='type1')
# plt.plot(x1,y1,'ro-')
plt.title('spec')
plt.xlabel('wavelength')
plt.ylabel('flux')
plt.legend()
plt.savefig('./specG0.png')
plt.show()
# Out:
# [141.27437 293.1337  235.3562  ...   0.        0.        0.     ]
# 353.99823
# -80.398094
# [3699.9863 3700.8384 3701.6907 ... 9092.852  9094.945  9097.04  ]
# 9097.04
# 3699.9863

# %% [markdown]
# G0

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
spec=fits.open("spec-55859-F5902_sp01-073.fits")
specdata = spec[0].data
flux1=specdata[0]
wavelenth=specdata[2]
print(flux1)
print(flux1.max())
print(flux1.min())
print(wavelenth)
print(wavelenth.max())
print(wavelenth.min())
x=np.arange(3699,9098)
x1=wavelenth
y1=flux1
plt.plot(x1,y1,'',color = 'black',label="SPEC",linewidth=0.3)#o-:圆形
plt.vlines(4100, -8, 293, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4340, -8, 293, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4860, -8, 293, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(6560, -8, 293, colors="c", linestyles="dashed",linewidth=0.2)
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
# l1=plt.plot(x1,y1,'r--',label='type1')
# plt.plot(x1,y1,'ro-')
plt.title('spec')
plt.xlabel('wavelength')
plt.ylabel('flux')
plt.legend()
plt.savefig('./specA7IV.png')
plt.show()
# Out:
# [235.37766 202.88838 214.76941 ...   0.        0.        0.     ]
# 292.8352
# -7.4694314
# [3699.9863 3700.8384 3701.6907 ... 9092.852  9094.945  9097.04  ]
# 9097.04
# 3699.9863

# %% [markdown]
# A7IV

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
spec=fits.open("spec-55859-F5902_sp01-137.fits")
specdata = spec[0].data
flux1=specdata[0]
wavelenth=specdata[2]
print(flux1)
print(flux1.max())
print(flux1.min())
print(wavelenth)
print(wavelenth.max())
print(wavelenth.min())
x=np.arange(3699,9098)
x1=wavelenth
y1=flux1
plt.plot(x1,y1,'',color = 'black',label="SPEC",linewidth=0.3)#o-:圆形
plt.vlines(4100, -54, 270, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4340, -54, 270, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4860, -54, 270, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(6560, -54, 270, colors="c", linestyles="dashed",linewidth=0.2)
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
# l1=plt.plot(x1,y1,'r--',label='type1')
# plt.plot(x1,y1,'ro-')
plt.title('spec')
plt.xlabel('wavelength')
plt.ylabel('flux')
plt.legend()
plt.savefig('./spec_dM1.png')
plt.show()
# Out:
# [68.545586   4.4757023 99.809425  ... 90.99154   15.086033   0.       ]
# 269.32922
# -53.897953
# [3699.9863 3700.8384 3701.6907 ... 9092.852  9094.945  9097.04  ]
# 9097.04
# 3699.9863

# %% [markdown]
# dM1

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
spec=fits.open("spec-58099-HIP29425K201_sp03-242.fits")
specdata = spec[0].data
flux1=specdata[0]
wavelenth=specdata[2]
print(flux1)
print(flux1.max())
print(flux1.min())
print(wavelenth)
print(wavelenth.max())
print(wavelenth.min())
x=np.arange(3699,9098)
x1=wavelenth
y1=flux1
plt.plot(x1,y1,'',color = 'black',label="SPEC",linewidth=0.3)#o-:圆形
plt.vlines(4100, 0, 998, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4340, 0, 998, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(4860, 0, 998, colors="c", linestyles="dashed",linewidth=0.2)
plt.vlines(6560, 0, 998, colors="c", linestyles="dashed",linewidth=0.2)
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
# l1=plt.plot(x1,y1,'r--',label='type1')
# plt.plot(x1,y1,'ro-')
plt.title('spec')
plt.xlabel('wavelength')
plt.ylabel('flux')
plt.legend()
plt.savefig('./specB6.png')
plt.show()
# Out:
# [383.59387 499.26895 546.61664 ...   0.        0.        0.     ]
# 997.3247
# 0.0
# [3699.9863 3700.8384 3701.6907 ... 9084.48   9086.573  9088.665 ]
# 9088.665
# 3699.9863

# %% [markdown]
# B6
